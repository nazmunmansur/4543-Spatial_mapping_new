# %%
import json

geojson_data = {
  "type": "FeatureCollection",
  "features": [
    {
      "type": "Feature",
      "properties": {
        "ADMIN": "United States of America",
        "ISO_A3": "USA"
      },
      "geometry": {
        "type": "Polygon",
        "coordinates": [[
          [-125, 24], [-66, 24], [-66, 49], [-125, 49], [-125, 24]
        ]]
      }
    },
    {
      "type": "Feature",
      "properties": {
        "ADMIN": "France",
        "ISO_A3": "FRA"
      },
      "geometry": {
        "type": "Polygon",
        "coordinates": [[
          [-5, 42], [8, 42], [8, 51], [-5, 51], [-5, 42]
        ]]
      }
    },
    {
      "type": "Feature",
      "properties": {
        "ADMIN": "Japan",
        "ISO_A3": "JPN"
      },
      "geometry": {
        "type": "Polygon",
        "coordinates": [[
          [129, 31], [146, 31], [146, 45], [129, 45], [129, 31]
        ]]
      }
    }
  ]
}

# Save to file
with open("countries_export.geojson", "w") as f:
    json.dump(geojson_data, f, indent=2)

print("File saved successfully!")
# Out:
# File saved successfully!
