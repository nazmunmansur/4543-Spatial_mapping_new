# %% [markdown]
# ## 04-Project Wordle

# %% [markdown]
# -I have started the wprdle project by establishing the wdo library file in the current working directry to "C:\Users\Nazmun\OneDrive - Midwestern State University\Documents\GitHub\4543-Spatial_mapping_new\04-Worldle Project"
#  folder.
#
# -01-Editable installs of wdo.ipynb: For data I have downloaded the "world_countries.json" file to see how the data look like and what information the data have. I want to ensure that the data has both "ISO-2" and "ISO-3"codes. As I found that the countries.json file in the flag folder has the ISO-2 code. I was trying to mergeing the data on the basis of the ISO-2 code in the "01-Editable installs of wdo.ipynb" notebook. How ever, I found that it's not showing any matching countries bsed on their "ISO-2" code.
#
# -02-Meet the Data.ipynb: Looking the features for both the country and flag data, we can see that the "ISO3166-1-Alpha-2" field in the country data corresponds to the "code" field in the flag index. This means we can use these fields to match countries with their respective flags. I tried the approach in notebook 01. And failed to get any matching countries. So I took the different appraoch by creating a dictionary by merging the feature property "name". So the goal was to combining the all the features from country and flag data to a new dictionary country_lookup file. And getting an output file of allt he information named "world_countries_lookup.json" file and converted it into geojson file named "converted.geojson".

# %% [markdown]
# -03-drawing the map.ipynb: I wrote the relevent wdo codes for the following:
#     *wdo.maps.leaflet_helpers file
#     *feature_center, fix_antimeridian, largest_polygon_only in the wdo.geometry.bbox file
#     *get_country_feature in the wdo.io.geojson_tools file.
# My goal was to using the wdo files to call in and make the code clearer also getting the actual result for the data.

# %% [markdown]
# -04-Find the middle of the country notebook: There was a task given to find check the center on the world map. Sanity-check task: plot a red dot at each country's center on a world map. Scan for any that fall in the ocean or on the wrong continent. Russia and the U.S. will misbehave. Note it in your write-up; don't try to fix the antimeridian — that's a rabbit hole.
#
# when I projeced the red dot in the world map it showed some interesing fact. The larger countries such as United States and Russia misbehaves with the center. I checked the bbox information in geojson.io to see how it's representing the country. The mean center was showing a cordiante inside the country but not actually the center for both United States and Russia. However, it was representing the center better for smaller countries such as Algeria, Spain, Nauru.
#
# I am using the feature_center_mean function to get the center of the country. I am also using the largest_polygon_only function to get the largest polygon of the country to get a more accurate center point. I am also using the add_geojson function added in the wdo.geometry.bbox file.
#
# Finally I was able to get the bbox center and mean center calculated.
