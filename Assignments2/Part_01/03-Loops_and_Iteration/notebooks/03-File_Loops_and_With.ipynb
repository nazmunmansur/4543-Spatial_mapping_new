# %% [markdown]
# # 📘 03 - File Loops and `with`
#
# Use `with open(...)` to read files and process content.

# %% [markdown]
# ## ✅ Learning Goals
# - Open and read files using `with`
# - Loop over lines in a file
# - Use `.strip()` and `.split()` to process text

# %%
# 📝 Sample file read
with open('sample.txt', 'r') as file:
    for line in file:
        print(line.strip())
# Out:
# Name: Nazmun Mansur
# Address: Wichita Falls
# State: Texas 76310
# I am an employee of MSU
# I am also studying

# %%
# 🔍 Process each line
with open('sample.txt', 'r') as f:
    for line in f:
        parts = line.strip().split(',')
        print('Parts:', parts)
# Out:
# Parts: ['Name: Nazmun Mansur']
# Parts: ['Address: Wichita Falls']
# Parts: ['State: Texas 76310']
# Parts: ['I am an employee of MSU']
# Parts: ['I am also studying']

# %% [markdown]
# ### ✏️ Your Turn
# Open a text file and print all lines that contain more than 3 words.

# %%
# Tip: use `len(line.split()) > 3` to check

# %%
with open('data.txt', 'r') as file:
    for line in file:
        if len(line.split()) > 3:
            print(line.strip())
# Out:
# I like to cook.
# I like to spent time with my kids.
# I love to study too.
# I wonder I have 3 wishes to make
# My family is everything to me.

# %%
for i in range(3): 
    print("Loop:", i)
# Out:
# Loop: 0
# Loop: 1
# Loop: 2

# %%
with open('data.txt', 'r') as file:
    # file operations here, e.g., reading the content
    content = file.read()
    print(content)
# Out:
# I like to cook.
# I like to spent time with my kids.
# I love to study too.
# I wonder I have 3 wishes to make
# My family is everything to me.
