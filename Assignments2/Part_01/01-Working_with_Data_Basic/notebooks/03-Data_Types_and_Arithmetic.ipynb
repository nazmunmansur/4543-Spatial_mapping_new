# %% [markdown]
# # 📘 03 - Data Types and Arithmetic
#
# Explore Python basics like variables, data types, and arithmetic operations.

# %% [markdown]
# ## ✅ Learning Goals
# - Understand Python data types
# - Use variables and print statements
# - Perform basic arithmetic

# %%
# 🧠 Variables and Types
x = 10
y = 3.5
z = 'hello'
print(type(x), type(y), type(z))
# Out:
# <class 'int'> <class 'float'> <class 'str'>

# %%
# ➕ Arithmetic Operations
print('Add:', x + y)
print('Divide:', x / y)
print('Floor Divide:', x // y)
print('Exponent:', x ** 2)
# Out:
# Add: 13.5
# Divide: 2.857142857142857
# Floor Divide: 2.0
# Exponent: 100

# %% [markdown]
# ## ✏️ Try It Yourself
# - Create your own variables
# - Try combining numbers and strings
# - Use `input()` to interact

# %%
# Your code here
name = input('What is your name? ')
print('Welcome,', name)
# Out:
# Welcome, Angel

# %% [markdown]
# # My code for creating variables and using input() to interact

# %%
user_name = "Alice"
user_age_str = 30
welcome_message = "Hello"
suffix = "!"

# Use the input() function to get information from the user
user_name = input("What is your name? ")
user_age_str = input("How old are you? ")
print('Welcome, ' + user_name + suffix )
print(user_name + " is " + user_age_str + suffix)
# Out:
# Welcome, Alice!
# Alice is 32!

# %% [markdown]
# ## 📤 Submit
# Make sure your name is at the top in a Markdown cell.
# Submit via D2L or Colab link.
