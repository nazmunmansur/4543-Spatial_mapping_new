# %% [markdown]
# # 🔬 Visualization Mini-Lab: Trends and Outliers
#
# Now it’s time to put your skills to the test!
# In this mini-lab, you’ll explore a real dataset, create visualizations, and identify **trends and outliers**.
#
# We’ll use the famous **Penguins dataset** (thanks to Seaborn).

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load dataset
penguins = sns.load_dataset("penguins")
#penguins = pd.read_csv("../../data/penguins.csv")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ## 1. Explore Distributions
#
# First, let’s look at the distribution of **body mass**.

# %%
sns.histplot(data=penguins, x="body_mass_g", kde=True, hue="species")
plt.title("Distribution of Body Mass by Species")
plt.show()

# %% [markdown]
# 👉 **Task:** Do some species have higher average body mass than others?

# %% [markdown]
# Yes, Gentoo has heigher average body mass than others.

# %% [markdown]
# ## 2. Relationships Between Variables
#
# Scatterplots help us see trends between two quantitative variables.

# %%
sns.scatterplot(data=penguins, x="flipper_length_mm", y="body_mass_g", hue="species")
plt.title("Flipper Length vs Body Mass")
plt.show()

# %% [markdown]
# 👉 **Task:** Which species tends to have longer flippers AND higher body mass?

# %% [markdown]
# Gento species has longer Flipper than other spices.

# %% [markdown]
# ## 3. Box Plots for Outliers
#
# Box plots are great for spotting outliers.

# %%
sns.boxplot(data=penguins, x="species", y="bill_length_mm", palette="Set2")
plt.title("Bill Length by Species")
plt.show()
# Out:
# /tmp/ipython-input-722458408.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=penguins, x="species", y="bill_length_mm", palette="Set2")

# %% [markdown]
# 👉 **Task:** Can you spot any outliers in the bill length data?

# %% [markdown]
# Yes, Gentoo has an outlier.

# %% [markdown]
# ## 4. Correlation Heatmap
#
# Correlation heatmaps let us see overall variable relationships.

# %%
corr = penguins.dropna().corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm", center=0)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# 👉 **Task:** Which variables appear to be strongly correlated?

# %% [markdown]
# flipper_length and body_mass variables apperas to be strongly correlated. In the Correlation Heatmap, the correlation between these two varribles is 0.87.

# %% [markdown]
# ## 5. Your Turn
#
# - Try a different dataset (e.g., `tips`, `iris`).
# - Create **at least 2 plots** that reveal a trend.
# - Create **1 plot** that highlights possible outliers.
# - Write a short summary of your findings.
#
# > Remember: The goal is to **use visualizations to tell a story about the data.**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load a sample dataset for tips
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(data=tips, x="tip", kde=True, hue="sex")
plt.title("Distribution of tip by Sex")
plt.show()

# %%
#Scatter plot for tip and sex
sns.scatterplot(data=tips, x="tip", y="total_bill", hue="sex")
plt.title("Tip vs Total_bill")
plt.show()

# %%
#Creating box plot for outlier
sns.boxplot(data=tips, x="sex", y="total_bill", palette="Set2")
plt.title("Total Bill by Sex")
plt.show()
# Out:
# /tmp/ipython-input-2179583294.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=tips, x="sex", y="total_bill", palette="Set2")

# %%
#Correlation heatmap
corr = tips.dropna().corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm", center=0)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Summary: From the histogram and scatterplot it is eveident that male persons are spending more than female persons. The boxplot represents that the male gender is spending more in term of total_bill for their dinner. The varriables total_bill and tips has a stronger correlation of 0.68 in the tips data set.

# %%
#Total bill by sex
sns.histplot(data=tips, x="total_bill", kde=True, hue="sex")
plt.title("Distribution of total_bill by Sex")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load a sample dataset for iris
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ---
# ✅ Congratulations! You’ve completed the visualization mini-lab and Week 07.
#
# Next module → Working with larger datasets and diving deeper into analysis.
