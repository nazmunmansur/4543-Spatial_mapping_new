# %% [markdown]
# # 📂 03 - Working with Files and Paths
#
# Data science means working with files all the time: datasets, config files, logs.
# This notebook introduces:
# - Checking your current path in Jupyter
# - Navigating directories
# - Reading and writing text files
# - Using `with` for safe file handling
# - Basics of JSON and CSV I/O

# %% [markdown]
# ## 1. Where Am I?

# %%
# %pwd  # Print current working directory
# Out:
# '/workspaces/4543-Spatial_mapping_new/Assignments2/Part_01/04-Foundations/notebooks'

# %%
# %ls  # List files in the current directory
# Out:
# 01-magic_commands.ipynb
# 02-markdown_and_formatting.ipynb
# 03-working_with_files_and_paths.ipynb
# 04-data_input_output.ipynb
# 05-plotting_basics.ipynb
# 06-jupyter_shortcuts_and_productivity.ipynb
# 07-using_help_and_docs.ipynb
# 08-timing_and_performance.ipynb
# Foundations_Quiz.ipynb
# meta.yaml

# %%
# %cd ..  # Change to parent directory
# Out:
# [Errno 2] No such file or directory: '.. # Change to parent directory'
# /workspaces/4543-Spatial_mapping_new/Assignments2/Part_01/04-Foundations/notebooks
# 01-magic_commands.ipynb
# 02-markdown_and_formatting.ipynb
# 03-working_with_files_and_paths.ipynb
# 04-data_input_output.ipynb
# 05-plotting_basics.ipynb
# 06-jupyter_shortcuts_and_productivity.ipynb
# 07-using_help_and_docs.ipynb
# 08-timing_and_performance.ipynb
# Foundations_Quiz.ipynb
# meta.yaml

# %% [markdown]
# ✅ **Your Turn**: Navigate into a subfolder of your repo (e.g., `Foundations/`) and list its contents.

# %%
# %cd 04-Foundations
# %pwd
# %ls
# Out:
# [Errno 2] No such file or directory: '04-Foundations'
# /workspaces/4543-Spatial_mapping_new/Assignments2/Part_01/04-Foundations/notebooks
# 01-magic_commands.ipynb
# 02-markdown_and_formatting.ipynb
# 03-working_with_files_and_paths.ipynb
# 04-data_input_output.ipynb
# 05-plotting_basics.ipynb
# 06-jupyter_shortcuts_and_productivity.ipynb
# 07-using_help_and_docs.ipynb
# 08-timing_and_performance.ipynb
# Foundations_Quiz.ipynb
# meta.yaml

# %% [markdown]
# ## 2. Writing and Reading Text Files

# %%
# Writing to a text file
with open("example.txt", "w") as f:
    f.write("Hello, Jupyter!\n")
    f.write("This is a text file.\n")

# %%
# Reading from a text file
with open("example.txt", "r") as f:
    contents = f.read()
contents
# Out:
# 'Hello, Jupyter!\nThis is a text file.\n'

# %% [markdown]
# ✅ **Your Turn**: Write your name into a file called `me.txt`, then read it back and print the result.

# %%
#Writing code for the me.txt file
with open("me.txt", "w") as f:
    f.write("Hello, Mustangs!\n")
    f.write("Go Mustangs. This is a text file.\n")
# Reading from a me.txt file
with open("me.txt", "r") as f:
    contents = f.read()
contents
# Out:
# 'Hello, Mustangs!\nGo Mustangs. This is a text file.\n'

# %% [markdown]
# ## 3. JSON Files

# %%
import json

data = {"name": "Graylian", "type": "mascot", "skills": ["howl", "parrot talk"]}

# Write JSON
with open("data.json", "w") as f:
    json.dump(data, f)

# Read JSON
with open("data.json", "r") as f:
    loaded = json.load(f)
loaded
# Out:
# {'name': 'Graylian', 'type': 'mascot', 'skills': ['howl', 'parrot talk']}

# %% [markdown]
# ✅ **Your Turn**: Create a dictionary with your name and 2-3 favorite courses. Save it to `courses.json`, then read it back.

# %%
# Creating my dictionary
Nazmun_Mansur = {"name": "Nazmun", "Course_1": "Econometrics", "Course_2": "Survival_Analysis", "Major" : "Applied_Statistics"}

# Write JSON
with open("Nazmun_Mansur.json", "w") as f:
    json.dump(Nazmun_Mansur, f)

# Read JSON
with open("Nazmun_Mansur.json", "r") as f:
    loaded = json.load(f)
loaded
# Out:
# {'name': 'Nazmun',
#  'Course_1': 'Econometrics',
#  'Course_2': 'Survival_Analysis',
#  'Major': 'Applied_Statistics'}

# %% [markdown]
# ## 4. CSV Files

# %%
import csv

# Writing CSV
rows = [["Name", "Score"], ["Alice", 90], ["Bob", 85]]
with open("scores.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(rows)

# Reading CSV
with open("scores.csv", "r") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Score']
# ['Alice', '90']
# ['Bob', '85']

# %% [markdown]
# ✅ **Your Turn**: Create a CSV with 3 rows of your own data (e.g., pets, grades, or hobbies). Read it back and display the rows.

# %%
# Writing CSV for own data
rows = [["Pet", "Grades"], ["cat", 2], ["bird", 8]]
with open("own.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(rows)

# Reading CSV for the file name own.csv
with open("own.csv", "r") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['Pet', 'Grades']
# ['cat', '2']
# ['bird', '8']

# %% [markdown]
# ---
# ### Summary
# - `%pwd`, `%ls`, `%cd` show you where you are in the filesystem.
# - Use `with open(...)` to safely read/write files.
# - JSON is for structured data (key/value).
# - CSV is for tabular data (rows/columns).
# - Managing files is step 1 in any real data science project.
