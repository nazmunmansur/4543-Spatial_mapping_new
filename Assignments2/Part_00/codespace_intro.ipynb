# %% [markdown]
# # 📘 CodeSpace Intro
#
# Welcome to your first Jupyter notebook in CodeSpace's! If it's not, that's ok, this will be real easy.

# %% [markdown]
# ## ✅ Learning Goals
# - Run cells in a notebook
# - Edit Markdown and code
# - Save a copy to your own Drive

# %%
# 👋 Try running this cell!
print('Hello, Python Spatial World!')
# Out:
# Hello, Python Spatial World!

# %% [markdown]
# ## ✏️ Your Turn
# Modify the code below to print your name.

# %% [markdown]
# ## Main Codespace - Nazmun Mansur

# %%
print('Nazmun')
# Out:
# Nazmun

# %%
print('Terry')
# Out:
# Terry

# %% [markdown]
# ## 💾 Save a Copy
# - Go to **File > Save a copy in Colabs**.
# - Make sure it changed on your github repo.
#
# Move it to your `completed` folder.

# %%
import geojsonio
import json
from IPython.display import display

with open('campus_world.geojson') as f:
    geojson_data = f.read()

# Convert the dictionary to a JSON string if needed, 
# though the library often handles the dict directly
# contents = json.dumps(geojson_data) 

# Embed the geojson.io map
# The display function is an alias for embed() in the library
display(geojsonio.embed(geojson_data))
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/IPython/core/display.py:447: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=http://geojson.io/#data=data:application/json,%7B%0A%20%20%22type%22%3A%20%22FeatureCollection%22%2C%0A%20%20%22features%22%3A%20%5B%0A%20%20%20%20%7B%0A%20%20%20%20%20%20%22type%22%3A%20%22Feature%22%2C%0A%20%20%20%20%20%20%22properties%22%3A%20%7B%0A%20%20%20%20%20%20%20%20%22Name%22%3A%20%22Bolin%20Hall%22%2C%0A%20%20%20%20%20%20%20%20%22marker-color%22%3A%20%22%23FF0000%22%2C%0A%20%20%20%20%20%20%20%20%22marker-size%22%3A%20%22large%22%2C%0A%20%20%20%20%20%20%20%20%22marker-symbol%22%3A%20%22soccer%22%2C%0A%20%20%20%20%20%20%20%20%22fill%22%3A%20%22%23C392ff%22%2C%0A%20%20%20%20%20%20%20%20%22fill-width%22%3A%201%2C%0A%20%20%20%20%20%20%20%20%22fill-opacity%22%3A%200.25%0A%20%20%20%20%20%20%7D%2C%0A%20%20%20%20%20%20%22geometry%22%3A%20%7B%0A%20%20%20%20%20%20%20%20%22type%22%3A%20%22Point%22%2C%0A%20%20%20%20%20%20%20%20%22coordinates%22%3A%20%5B-98.51947%2C%2033.87372%5D%0A%20%20%20%20%20%20%7D%2C%0A%20%20%20%20%20%20%22id%22%3A%200%0A%20%20%20%20%7D%2C%0A%20%20%20%20%7B%0A%20%20%20%20%20%20%22type%22%3A%20%22Feature%22%2C%0A%20%20%20%20%20%20%22properties%22%3A%20%7B%0A%20%20%20%20%20%20%20%20%22Name%22%3A%20%22Bookstore%22%2C%0A%20%20%20%20%20%20%20%20%22marker-color%22%3A%20%22%2300ff00%22%2C%0A%20%20%20%20%20%20%20%20%22marker-symbol%22%3A%20%22library%22%2C%0A%20%20%20%20%20%20%20%20%22marker-size%22%3A%20%22large%22%0A%20%20%20%20%20%20%7D%2C%0A%20%20%20%20%20%20%22geometry%22%3A%20%7B%0A%20%20%20%20%20%20%20%20%22coordinates%22%3A%20%5B-98.52054301247594%2C%2033.873957083293334%5D%2C%0A%20%20%20%20%20%20%20%20%22type%22%3A%20%22Point%22%0A%20%20%20%20%20%20%7D%2C%0A%20%20%20%20%20%20%22id%22%3A%201%0A%20%20%20%20%7D%2C%0A%20%20%20%20%7B%0A%20%20%20%20%20%20%22type%22%3A%20%22Feature%22%2C%0A%20%20%20%20%20%20%22properties%22%3A%20%7B%0A%20%20%20%20%20%20%20%20%22name%22%3A%20%22Coffee%20shop%22%2C%0A%20%20%20%20%20%20%20%20%22marker-color%22%3A%20%22%23a0a0a0%22%2C%0A%20%20%20%20%20%20%20%20%22marker-size%22%3A%20%22large%22%2C%0A%20%20%20%20%20%20%20%20%22marker-symbol%22%3A%20%22cafe%22%0A%20%20%20%20%20%20%7D%2C%0A%20%20%20%20%20%20%22geometry%22%3A%20%7B%0A%20%20%20%20%20%20%20%20%22coordinates%22%3A%20%5B-98.51805044396598%2C%2033.87010225735909%5D%2C%0A%20%20%20%20%20%20%20%20%22type%22%3A%20%22Point%22%0A%20%20%20%20%20%20%7D%2C%0A%20%20%20%20%20%20%22id%22%3A%2011%0A%20%20%20%20%7D%2C%0A%20%20%20%20%7B%0A%20%20%20%20%20%20%22type%22%3A%20%22Feature%22%2C%0A%20%20%20%20%20%20%22properties%22%3A%20%7B%0A%20%20%20%20%20%20%20%20%22name%22%3A%20%22bounding%20box%22%2C%0A%20%20%20%20%20%20%20%20%22fill%22%3A%20%22%23ff00ff%22%2C%0A%20%20%20%20%20%20%20%20%22fill-opacity%22%3A%200.2%2C%0A%20%20%20%20%20%20%20%20%22stroke%22%3A%20%22%230000ff%22%0A%20%20%20%20%20%20%7D%2C%0A%20%20%20%20%20%20%22geometry%22%3A%20%7B%0A%20%20%20%20%20%20%20%20%22coordinates%22%3A%20%5B%0A%20%20%20%20%20%20%20%20%20%20%5B%0A%20%20%20%20%20%20%20%20%20%20%20%20%5B-98.52054301247594%2C%2033.873957083293334%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%5B-98.52054301247594%2C%2033.87010225735909%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%5B-98.51805044396598%2C%2033.87010225735909%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%5B-98.51805044396598%2C%2033.873957083293334%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%5B-98.52054301247594%2C%2033.873957083293334%5D%0A%20%20%20%20%20%20%20%20%20%20%5D%0A%20%20%20%20%20%20%20%20%5D%2C%0A%20%20%20%20%20%20%20%20%22type%22%3A%20%22Polygon%22%0A%20%20%20%20%20%20%7D%2C%0A%20%20%20%20%20%20%22id%22%3A%203%0A%20%20%20%20%7D%0A%20%20%5D%0A%7D%0A width=100% height=512></iframe>

# %%
from geojsonio import display

with open('campus_world.geojson') as f:
    contents = f.read()
    display(contents)
