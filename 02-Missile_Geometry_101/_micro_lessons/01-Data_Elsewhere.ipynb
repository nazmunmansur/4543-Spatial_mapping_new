# %% [markdown]
# # 01 — Data Elsewhere
#
# Most of the time, moving or copying files to where your code exists is isn't the best answer. Typically there will be a central or common location for data. In this case, the file we want lives in:
#
# - Data Location: `data/countries.geojson`
#
# - It is NOT in the current working directory.
# - Figure out the path relative to your cwd
# - Make sure you can read and print the target file.
#
# Tasks:
# 1. Print cwd
# 2. Build the path
# 3. Confirm it exists
# 4. Fail loudly if not

# %%
from pathlib import Path


## Use last items learned from last lesson to locate and check if the file exists 
## Remember parent, and folder: data

cwd = Path.cwd()
print("Current Working Directory:")
print(cwd)

target = cwd / "countries.geojson"
print("\nAttempting to access:")
print(target)

exists = target.exists()
print("\nDoes file exist?")
print(exists)

assert exists, (
    f"\n❌ ERROR: File not found:\n{target}\n"
    "Check spelling and folder structure."
)

print("\n✅ File located successfully.")
# Out:
# Current Working Directory:
# /workspaces/4543-Spatial_mapping_new
#
# Attempting to access:
# /workspaces/4543-Spatial_mapping_new/countries.geojson
#
# Does file exist?
# False
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 19
#      16 print("\nDoes file exist?")
#      17 print(exists)
# ---> 19 assert exists, (
#      20     f"\n❌ ERROR: File not found:\n{target}\n"
#      21     "Check spelling and folder structure."
#      22 )
#      24 print("\n✅ File located successfully.")
#
# AssertionError:
# ❌ ERROR: File not found:
# /workspaces/4543-Spatial_mapping_new/countries.geojson
# Check spelling and folder structure.

# %%
from pathlib import Path


## Use last items learned from last lesson to locate and check if the file exists 
## Remember parent, and folder: data

cwd = Path.cwd()
print("Current Working Directory:")
print(cwd)

#parent = cwd.parent
#print(parent)

# add data folder to end of path
#data_path = cwd / "data"
data_path = cwd / "data" / "countries.geojson"
#data_path = parent_lib / "data"
print("\nLooking for data folder at:")
print(data_path)

target = cwd / "data" / "countries.geojson"
#target = parent / "countries.geojson"
print("\nAttempting to access:")
print(target)

exists = target.exists()
print("\nDoes file exist?")
print(exists)

assert exists, (
    f"\n❌ ERROR: File not found:\n{target}\n"
    "Check spelling and folder structure."
)

print("\n✅ File located successfully.")
# Out:
# Current Working Directory:
# /workspaces/4543-Spatial_mapping_new
#
# Looking for data folder at:
# /workspaces/4543-Spatial_mapping_new/data/countries.geojson
#
# Attempting to access:
# /workspaces/4543-Spatial_mapping_new/data/countries.geojson
#
# Does file exist?
# True
#
# ✅ File located successfully.
