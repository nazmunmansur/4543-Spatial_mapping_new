# %% [markdown]
# ##  03 Find Project Root
#
# ## Goal
#
# - Sometimes notebooks are executed from different folders.
# - To build reliable paths, we can locate the **project root** automatically by searching upward for a marker such as `.git`.

# %% [markdown]
# ## Idea
#
# - If your project contains a `.git` folder, then that folder is a good marker for the project root.
# - We can start at the current working directory and move upward until we find it.

# %%
from pathlib import Path

def find_project_root(marker=".git"):
    path = Path.cwd()

    while path != path.parent:
        if (path / marker).exists():
            return path
        path = path.parent

    raise RuntimeError(f"Project root not found. Could not locate marker: {marker}")

# %%
try:
    root = find_project_root()
    print("Project root found:")
    print(root)

    data_path = root / "data" / "countries.geojson"
    print("\nExample data path from root:")
    print(data_path)
    print("Exists:", data_path.exists())
except RuntimeError as e:
    print("Notice:")
    print(e)
# Out:
# Project root found:
# c:\Users\Nazmun\OneDrive - Midwestern State University\Documents\GitHub\4543-Spatial_mapping_new
#
# Example data path from root:
# c:\Users\Nazmun\OneDrive - Midwestern State University\Documents\GitHub\4543-Spatial_mapping_new\data\countries.geojson
# Exists: True

# %% [markdown]
# ## Why This Matters
#
# - A root-finding function makes notebooks more reliable because the path logic does not depend as heavily on where the notebook happened to start.
#
# - This becomes especially useful once students begin using:
#
#   - `src/` layouts
#   - helper libraries
#   - nested notebook folders
#   - bigger projects

# %%
# Optional: inspect the current directory and its parents
current = Path.cwd()
print("Current directory and parents:")
for p in [current, *current.parents]:
    print(" -", p)
# Out:
# Current directory and parents:
#  - c:\Users\Nazmun\OneDrive - Midwestern State University\Documents\GitHub\4543-Spatial_mapping_new\02-Missile_Geometry_202\_micro_lessons\00-Paths
#  - c:\Users\Nazmun\OneDrive - Midwestern State University\Documents\GitHub\4543-Spatial_mapping_new\02-Missile_Geometry_202\_micro_lessons
#  - c:\Users\Nazmun\OneDrive - Midwestern State University\Documents\GitHub\4543-Spatial_mapping_new\02-Missile_Geometry_202
#  - c:\Users\Nazmun\OneDrive - Midwestern State University\Documents\GitHub\4543-Spatial_mapping_new
#  - c:\Users\Nazmun\OneDrive - Midwestern State University\Documents\GitHub
#  - c:\Users\Nazmun\OneDrive - Midwestern State University\Documents
#  - c:\Users\Nazmun\OneDrive - Midwestern State University
#  - c:\Users\Nazmun
#  - c:\Users
#  - c:\

# %% [markdown]
# ## Exercise A
#
# Answer without writing code:
#
# 1. What happens when `find_project_root()` is called in a project with no `.git` folder?
# Answer: It might fail, raise an exception or return to fallback path
# 2. Name two other files or folders that could serve as a reliable project root marker.
# Answer: setup.py and/or src/ directory
# 3. Why is locating the root this way more robust than assuming the notebook always runs from the same folder?
# Answer: Helps to prevent file not found error. It handles inconsistencies when running notebooks from different user's home directory.

# %% [markdown]
# ## Exercise B
#
# Call `find_project_root()` with a different marker.
#
# 1. Try `"pyproject.toml"` — does it find a root? What does that tell you?
# 2. Try a marker that definitely doesn't exist (e.g. `"banana"`) — what happens, and why is the `RuntimeError` message useful?

# %%
from pathlib import Path

# Change the marker to "pyproject.toml" and test what happens.

def find_project_root(marker="pyproject.toml"):
    path = Path.cwd()

    while path != path.parent:
        if (path / marker).exists():
            return path
        path = path.parent

    raise RuntimeError(f"Project root not found. Could not locate marker: {marker}")

# Then try a marker that definitely doesn't exist (e.g. "banana").
# Your code here

# %%
try:
    root = find_project_root()
    print("Project root found:")
    print(root)

    data_path = root / "data" / "countries.geojson"
    print("\nExample data path from root:")
    print(data_path)
    print("Exists:", data_path.exists())
except RuntimeError as e:
    print("Notice:")
    print(e)
# Out:
# Notice:
# Project root not found. Could not locate marker: pyproject.toml

# %%
#Try a marker that definitely doesn't exist (e.g. `"banana"`) — what happens, and why is the `RuntimeError` message useful?
from pathlib import Path

# Change the marker to "pyproject.toml" and test what happens.

def find_project_root(marker="banana"):
    path = Path.cwd()

    while path != path.parent:
        if (path / marker).exists():
            return path
        path = path.parent

    raise RuntimeError(f"Project root not found. Could not locate marker: {marker}")

# %%
try:
    root = find_project_root()
    print("Project root found:")
    print(root)

    data_path = root / "data" / "countries.geojson"
    print("\nExample data path from root:")
    print(data_path)
    print("Exists:", data_path.exists())
except RuntimeError as e:
    print("Notice:")
    print(e)
# Out:
# Notice:
# Project root not found. Could not locate marker: banana

# %% [markdown]
# ## Exercise C
#
# Use `find_project_root()` to build a reliable path to this module's `countries.geojson` data file.
#
# Use the directory tree printed above to figure out the correct subfolders from root, then replace `"???"` in the cell below.

# %%
#to redefine the root
from pathlib import Path

# Change the marker to "pyproject.toml" and test what happens.

def find_project_root(marker="pyproject.toml"):
    path = Path.cwd()

    while path != path.parent:
        if (path / marker).exists():
            return path
        path = path.parent

    raise RuntimeError(f"Project root not found. Could not locate marker: {marker}")

# %%
from pathlib import Path

root = find_project_root()

# Build the path from root to this module's data folder and check countries.geojson
# Hint: look at the directory tree printed above to figure out the right subfolders
data_file = root / "data" / "countries.geojson"

print("Looking for:", data_file)
print("Exists:", data_file.exists())
# Out:
# Looking for: c:\Users\Nazmun\OneDrive - Midwestern State University\Documents\GitHub\4543-Spatial_mapping_new\data\countries.geojson
# Exists: True

# %% [markdown]
# ## Optional Advanced — Multiple Markers and Custom Start
#
# Extend `find_project_root` to accept:
#
# - `markers` — a list of marker names; stop at the first directory that contains **any** of them
# - `start` — an optional starting path (defaults to `Path.cwd()` if not given)
#
# This lets you test the function from any location and makes it more flexible for projects that don't use git.

# %%
from pathlib import Path

def find_project_root_multi(markers=(".git", "pyproject.toml", "setup.py"), start: Path = None):
    """Return the first ancestor directory that contains any of the marker files/folders."""
    # Your code here
    if start is None:
        start_path = Path.cwd()
    else:
        start_path = Path(start).resolve()

    for parent in [start_path] + list(start_path.parents):
        for marker in markers:
            if (parent / marker).exists():
                return parent

    raise FileNotFoundError(f"No project root found with markers {markers} starting from {start_path}")
    pass

root = find_project_root_multi()
print("Root:", root)
# Out:
# Root: c:\Users\Nazmun\OneDrive - Midwestern State University\Documents\GitHub\4543-Spatial_mapping_new

# %% [markdown]
# ## Check Your Understanding
#
# 1. `find_project_root()` walks upward until `path == path.parent`. What does that condition mean — when does it become true?
# 2. You call `find_project_root()` from a notebook and get back `/project`. You then write `root / "data" / "cities.json"`. What is the full absolute path that produces?
# 3. A teammate hardcodes `Path("/Users/them/project/data/cities.json")` instead of using `find_project_root()`. What breaks when you run their notebook?

# %% [markdown]
# ---
# # Summary
#
# ## Students should now understand
#
# - what the working directory is
# - how relative and absolute paths differ
# - how to build paths into other folders
# - how to check whether files exist
# - how to locate a project root marker
#
# ## Recommended next step
#
# Move into:
#
# `01_JSON_GeoJSON`
#
# because now students are ready to locate files **before** opening and inspecting them.
#
# That tiny detail saves a lot of chaos later. A shocking amount, really.
