# %% [markdown]
# ## 02 — Filtering Features
#
# So far every feature in the file appears on the map. Filtering changes that — you decide **which features to show** before the map ever renders.
#
# ```
# full dataset  →  filter  →  subset  →  map
# ```
#
# This is where the map stops being a static picture of a file and starts being a **view into your data**.

# %% [markdown]
# ## Setup

# %%
import json
from ipyleaflet import Map, GeoJSON

WICHITA_FALLS = (33.9137, -98.4934)

with open("../02-Viewing_GeoJSON/data/wichita_falls.geojson") as f:
    geojson = json.load(f)

print(f"{len(geojson['features'])} features loaded")
for feat in geojson["features"]:
    print(f"  {feat['geometry']['type']:12}  {feat['properties']['name']}")
# Out:
# 6 features loaded
#   Point         Wichita Falls City Hall
#   Point         Midwestern State University
#   Point         Lake Wichita
#   Point         Lucy Park
#   LineString    MSU to City Hall route
#   Polygon       Lake Wichita Park

# %% [markdown]
# ## Simple Property Filter
#
# Filtering is a list comprehension with an `if` condition. The result is a plain Python list of feature dicts.
#
# ```python
# filtered = [
#     f for f in geojson["features"]
#     if <condition on f["properties"]>
# ]
# ```

# %%
# Keep only features whose type is "park"
park_features = [
    f for f in geojson["features"]
    if f["properties"].get("type") == "park"
]

print(f"{len(park_features)} park features:")
for f in park_features:
    print(f"  {f['properties']['name']}")
# Out:
# 2 park features:
#   Lucy Park
#   Lake Wichita Park

# %% [markdown]
# ## Rebuilding a FeatureCollection
#
# A filtered list is just a list — not a valid GeoJSON object. To pass it to `GeoJSON()`, wrap it back into a FeatureCollection dict.
#
# ```python
# filtered_geojson = {
#     "type": "FeatureCollection",
#     "features": filtered_list
# }
# ```
#
# This is the pattern you will use every time you filter.

# %%
park_fc = {
    "type": "FeatureCollection",
    "features": park_features
}

m = Map(center=WICHITA_FALLS, zoom=12)
m.add(GeoJSON(data=park_fc))
m

# %% [markdown]
# ## Filtering by Geometry Type
#
# You can also filter on the `geometry` side of the feature — not just `properties`. This is useful when you want to control how different geometry types are displayed.

# %%
# Keep only Point features
point_fc = {
    "type": "FeatureCollection",
    "features": [
        f for f in geojson["features"]
        if f["geometry"]["type"] == "Point"
    ]
}

m = Map(center=WICHITA_FALLS, zoom=12)
m.add(GeoJSON(data=point_fc))
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## Numeric Filtering
#
# When a property holds a number, use comparison operators (`>`, `<`, `>=`, `<=`) in the filter condition.
#
# Our `wichita_falls.geojson` does not have numeric properties, so here is a small inline dataset with a `priority` score. The pattern is identical for any real dataset.

# %%
# Inline dataset with a numeric "priority" property
sites = {
    "type": "FeatureCollection",
    "features": [
        {"type": "Feature", "geometry": {"type": "Point", "coordinates": [-98.49, 33.91]}, "properties": {"name": "Alpha",   "priority": 92}},
        {"type": "Feature", "geometry": {"type": "Point", "coordinates": [-98.51, 33.89]}, "properties": {"name": "Bravo",   "priority": 45}},
        {"type": "Feature", "geometry": {"type": "Point", "coordinates": [-98.53, 33.87]}, "properties": {"name": "Charlie", "priority": 78}},
        {"type": "Feature", "geometry": {"type": "Point", "coordinates": [-98.50, 33.93]}, "properties": {"name": "Delta",   "priority": 15}},
        {"type": "Feature", "geometry": {"type": "Point", "coordinates": [-98.47, 33.88]}, "properties": {"name": "Echo",    "priority": 61}},
    ]
}

# Only show high-priority sites (score >= 60)
high_priority = {
    "type": "FeatureCollection",
    "features": [
        f for f in sites["features"]
        if f["properties"]["priority"] >= 60
    ]
}

print("High-priority sites:")
for f in high_priority["features"]:
    print(f"  {f['properties']['name']}  ({f['properties']['priority']})")

m = Map(center=WICHITA_FALLS, zoom=12)
m.add(GeoJSON(data=high_priority))
m
# Out:
# High-priority sites:
#   Alpha  (92)
#   Charlie  (78)
#   Echo  (61)
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## Combining Filtering and Styling
#
# Filtering and styling are independent steps — filter first, then style. The pipeline is:
#
# ```
# raw GeoJSON
#     ↓  filter (list comprehension)
# subset list
#     ↓  wrap into FeatureCollection
# filtered GeoJSON
#     ↓  GeoJSON(data=..., style=...)
# styled map layer
# ```

# %%
COLOR_MAP = {
    "park":       "#2ecc71",
    "water":      "#1abc9c",
    "education":  "#3498db",
    "government": "#e74c3c",
    "route":      "#e67e22",
}

def style_by_type(feature):
    color = COLOR_MAP.get(feature["properties"].get("type"), "#95a5a6")
    return {"color": color, "fillColor": color, "fillOpacity": 0.5, "weight": 2}

# Filter: only non-route features
no_routes_fc = {
    "type": "FeatureCollection",
    "features": [
        f for f in geojson["features"]
        if f["properties"].get("type") != "route"
    ]
}

# Style and display
m = Map(center=WICHITA_FALLS, zoom=12)
m.add(GeoJSON(data=no_routes_fc, style_route=style_by_type))
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## Filtering into Multiple Layers
#
# You can filter the same dataset multiple ways to create distinct named layers. Combined with `LayersControl`, this gives the user a toggle for each group.

# %%
from ipyleaflet import LayersControl

def make_fc(features):
    return {"type": "FeatureCollection", "features": features}

natural_layer = GeoJSON(
    data=make_fc([f for f in geojson["features"] if f["properties"].get("type") in ("park", "water")]),
    name="Natural Features",
    style={"color": "#27ae60", "fillColor": "#27ae60", "fillOpacity": 0.45, "weight": 2}
)

built_layer = GeoJSON(
    data=make_fc([f for f in geojson["features"] if f["properties"].get("type") in ("government", "education")]),
    name="Built Environment",
    style={"color": "#2980b9", "fillColor": "#2980b9", "fillOpacity": 0.45, "weight": 2}
)

route_layer = GeoJSON(
    data=make_fc([f for f in geojson["features"] if f["properties"].get("type") == "route"]),
    name="Routes",
    style={"color": "#e67e22", "weight": 3, "opacity": 0.8}
)

m = Map(center=WICHITA_FALLS, zoom=12)
m.add(natural_layer)
m.add(built_layer)
m.add(route_layer)
m.add(LayersControl())
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# Each filter produces one layer. The `LayersControl` lets you toggle each group independently.

# %% [markdown]
# ## Advanced Filtering: Compound Conditions
#
# Use `and` / `or` to combine multiple conditions in one filter.
#
# ```python
# # AND — both conditions must be true
# f["properties"]["type"] == "park" and f["geometry"]["type"] == "Polygon"
#
# # OR — either condition is enough
# f["properties"]["type"] == "park" or f["properties"]["type"] == "water"
#
# # IN — cleaner way to write OR against a fixed set
# f["properties"]["type"] in ("park", "water")
# ```

# %%
# Points that are either parks or water
natural_points = {
    "type": "FeatureCollection",
    "features": [
        f for f in geojson["features"]
        if f["geometry"]["type"] == "Point"
        and f["properties"].get("type") in ("park", "water")
    ]
}

print(f"{len(natural_points['features'])} natural point features:")
for f in natural_points["features"]:
    print(f"  {f['properties']['name']}  ({f['properties']['type']})")

m = Map(center=WICHITA_FALLS, zoom=12)
m.add(GeoJSON(data=natural_points))
m
# Out:
# 2 natural point features:
#   Lake Wichita  (water)
#   Lucy Park  (park)
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %%
# Compound numeric + string filter on the sites dataset
high_and_early = {
    "type": "FeatureCollection",
    "features": [
        f for f in sites["features"]
        if f["properties"]["priority"] >= 60
        and f["properties"]["name"][0] <= "C"  # names starting A–C
    ]
}

print("High-priority, early-alphabet sites:")
for f in high_and_early["features"]:
    print(f"  {f['properties']['name']}  ({f['properties']['priority']})")
# Out:
# High-priority, early-alphabet sites:
#   Alpha  (92)
#   Charlie  (78)

# %% [markdown]
# Compound conditions are the foundation of **spatial queries** — once you add geometry operations (distance, containment, intersection), you will combine them here the same way.

# %% [markdown]
# ## Exercise A
#
# Filter `wichita_falls.geojson` to show only `Polygon` and `LineString` features (exclude all `Point` features). Apply `style_by_type` from the teaching cells and display the result.

# %%
from ipyleaflet import Map, GeoJSON

COLOR_MAP = {
    "park":       "#2ecc71",
    "water":      "#1abc9c",
    "education":  "#3498db",
    "government": "#e74c3c",
    "route":      "#e67e22",
}

def style_by_type(feature):
    color = COLOR_MAP.get(feature["properties"].get("type"), "#95a5a6")
    return {"color": color, "fillColor": color, "fillOpacity": 0.5, "weight": 2}

# Filter to only Polygon and LineString features (exclude Points)
# Apply style_by_type and display
# Your code here
line_poly = {
    "type": "FeatureCollection",
    "features": [
        f for f in geojson["features"]
        if f["geometry"]["type"] != "Point"
        and f["properties"].get("type")
    ]
}

# Style and display
m = Map(center=WICHITA_FALLS, zoom=12)
m.add(GeoJSON(data=line_poly, style_route=style_by_type))
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## Exercise B
#
# Load `meteorites.geojson` (hint: it's two levels up in `data/`). Filter to meteorites where **mass > 10000 and year is recorded** (not `None` or `0`). Display them on a world map and print the count.

# %%
import json
from ipyleaflet import Map, GeoJSON

with open("../data/meteorites.geojson") as f:
    meteorites = json.load(f)

feature = meteorites["features"][0]
feature

# Filter: mass > 10000 AND year is not None/0
# Display on a world map (center=(20, 0), zoom=2), print the count
# Your code here
# Out:
# {'type': 'Feature',
#  'properties': {'name': 'Aarhus',
#   'mass': 720,
#   'year': 1951,
#   'id': 2,
#   'fall': 'Fell',
#   'recclass': 'H6',
#   'marker-color': '#d879db',
#   'marker-size': 'small'},
#  'geometry': {'type': 'Point', 'coordinates': [10.23333, 56.18333]}}

# %%
# 2. Filter: mass > 10000 and year recorded (not None/0)
filtered_features = []
#mass = (meteorites.get('mass', 0))
#mass_int = int(mass) 
#year = (meteorites.get('year', 0))
#year_int = int(year)
for feature in meteorites['features']:
    props = feature.get('properties', {})
    mass = props.get('mass')
    year = props.get('year')

    try:
        mass_int = int(str(mass).strip())
    except (TypeError, ValueError):
        mass_int = 0

    try:
        year_int = int(str(year).strip())
    except (TypeError, ValueError):
        year_int = 0

    if mass_int > 10000 and year_int != 0:
        filtered_features.append(feature)

# Update the data structure with filtered features
filtered_data = {
    'type': 'FeatureCollection',
    'features': filtered_features
}

# 3. Print the count
print(f"Filtered meteorite count: {len(filtered_features)}")
print(f"{len(meteorites['features'])} meteorite features:")
for f in filtered_data["features"]:
    print(f"  {f['properties']['name']}  ({f['properties']['year']}) ({f['properties']['mass']})")

m = Map(center=(20, 0), zoom=2)
m.add(GeoJSON(data=filtered_data))
m
# Out:
# Filtered meteorite count: 1206
# 31963 meteorite features:
#   Abee  (1952) (107000)
#   Aïr  (1925) (24000)
#   Agen  (1814) (30000)
#   Akyumak  (1981) (50000)
#   Alfianello  (1883) (228000)
#   Allegan  (1899) (32000)
#   Allende  (1969) (2000000)
#   Andura  (1939) (17900)
#   Appley Bridge  (1914) (15000)
#   Aumale  (1865) (50000)
#   Ausson  (1858) (50000)
#   Bahjoi  (1934) (10322)
#   Bachmut  (1814) (18000)
#   Ban Rong Du  (1993) (16700)
#   Bandong  (1871) (11500)
#   Bansur  (1892) (15000)
#   Barwell  (1965) (44000)
#   Bassikounou  (2006) (29560)
#   Bath  (1892) (21000)
#   Baszkówka  (1994) (15500)
#   Bath Furnace  (1902) (86000)
#   Beardsley  (1929) (16000)
#   Beaver Creek  (1893) (14000)
#   Benguerir  (2004) (25000)
#   Beni M'hira  (2001) (19000)
#   Bensour  (2002) (45000)
#   Béréba  (1924) (18000)
#   Bilanga  (1999) (25000)
#   Bjurböle  (1899) (330000)
#   Boguslavka  (1916) (256000)
#   Braunau  (1847) (39000)
#   Bruderheim  (1960) (303000)
#   Bur-Gheluai  (1919) (120000)
#   Bursa  (1946) (25000)
#   Butsura  (1861) (29000)
#   Cabezo de Mayo  (1870) (25000)
#   Buzzard Coulee  (2008) (41000)
#   Cabin Creek  (1886) (48500)
#   Campos Sales  (1991) (23680)
#   Cangas de Onis  (1866) (34000)
#   Castrovillari  (1583) (15000)
#   Chajari  (1933) (18300)
#   Chantonnay  (1812) (31500)
#   Charsonville  (1810) (27000)
#   Charwallas  (1834) (12000)
#   Château-Renard  (1841) (30000)
#   Chelyabinsk  (2013) (100000)
#   Chergach  (2007) (100000)
#   Colby (Wisconsin)  (1917) (104000)
#   Conquista  (1965) (20350)
#   Cumberland Falls  (1919) (17000)
#   Dahmani  (1981) (18000)
#   Demina  (1911) (16400)
#   Devgaon  (2001) (12000)
#   Desuri  (1962) (25400)
#   Dergaon  (2001) (12500)
#   Dhajala  (1976) (45000)
#   Mezö-Madaras  (1852) (22700)
#   Miller (Arkansas)  (1930) (16700)
#   Millbillillie  (1960) (330000)
#   Mocs  (1882) (300000)
#   Modoc (1905)  (1905) (35000)
#   Molina  (1858) (144000)
#   Montferré  (1923) (149000)
#   Mount Browne  (1902) (11300)
#   Mount Tazerzait  (1991) (110000)
#   Mount Vaisi  (1637) (17000)
#   Murchison  (1969) (100000)
#   Murray  (1950) (12600)
#   Nakhon Pathom  (1923) (23200)
#   Nan Yang Pao  (1917) (52900)
#   Naoki  (1928) (17000)
#   Nerft  (1864) (10250)
#   New Concord  (1860) (230000)
#   New Halfa  (1994) (12000)
#   New Orleans  (2003) (19256)
#   N'Goureyma  (1900) (37500)
#   Ningbo  (1975) (14250)
#   N'Kandhla  (1912) (17200)
#   Norton County  (1948) (1100000)
#   Nuevo Mercurio  (1978) (50000)
#   Ochansk  (1887) (500000)
#   Ohaba  (1857) (16250)
#   Ogi  (1741) (14360)
#   Okniny  (1834) (12000)
#   Oldenburg (1930)  (1930) (16570)
#   Olivenza  (1924) (150000)
#   Olmedilla de Alarcón  (1929) (40000)
#   Omolon  (1981) (250000)
#   Orgueil  (1864) (14000)
#   Oum Dreyga  (2003) (17000)
#   Ourique  (1998) (20000)
#   Palinshih  (1914) (18000)
#   Pampanga  (1859) (10500)
#   Paragould  (1930) (408000)
#   Paranaiba  (1956) (100000)
#   Park Forest  (2003) (18000)
#   Parnallee  (1857) (77600)
#   Patwar  (1935) (37350)
#   Pavlograd  (1826) (40000)
#   Peace River  (1963) (45760)
#   Peekskill  (1992) (12570)
#   Peña Blanca Spring  (1946) (70000)
#   Perpeti  (1935) (23474)
#   Pervomaisky  (1933) (66000)
#   Phillips County (stone)  (1901) (57900)
#   Phuoc-Binh  (1941) (11000)
#   Pillistfer  (1863) (23250)
#   Piplia Kalan  (1996) (42000)
#   Portales Valley  (1998) (71400)
#   Pultusk  (1868) (250000)
#   Putinga  (1937) (300000)
#   Quesa  (1898) (10750)
#   Quija  (1990) (17450)
#   Raghunathpura  (1986) (10200)
#   Rahimyar Khan  (1983) (67225)
#   Rasgrad  (1740) (24700)
#   Reliegos  (1947) (17300)
#   Richardton  (1918) (90000)
#   Rose City  (1921) (10600)
#   Ryechki  (1914) (13000)
#   Saint-Séverin  (1966) (271000)
#   Saint-Sauveur  (1914) (14000)
#   Saratov  (1918) (200000)
#   Seoni  (1966) (20000)
#   Sevrukovo  (1874) (101000)
#   Shelburne  (1904) (18600)
#   Sikhote-Alin  (1947) (23000000)
#   Sivas  (1989) (40000)
#   Soko-Banja  (1877) (80000)
#   Sone  (1866) (17100)
#   Songyuan  (1993) (36900)
#   St. Mark's  (1903) (13780)
#   St. Michel  (1910) (17000)
#   Ställdalen  (1876) (34000)
#   Stannern  (1808) (52000)
#   Sterlitamak  (1990) (325000)
#   Strathmore  (1917) (13400)
#   Stretchleigh  (1623) (10400)
#   St-Robert  (1994) (25400)
#   Suizhou  (1986) (260000)
#   Sulagiri  (2008) (110000)
#   Tambakwatu  (1975) (10500)
#   Tamdakht  (2008) (100000)
#   Tatahouine  (1931) (12000)
#   Tauti  (1937) (21000)
#   Tennasilm  (1872) (28500)
#   Tenham  (1879) (160000)
#   Thika  (2011) (14200)
#   Thuathe  (2002) (45300)
#   Tieschitz  (1878) (28000)
#   Tilden  (1927) (74800)
#   Timochin  (1807) (65500)
#   Tjabe  (1869) (20000)
#   Tjerebon  (1922) (16500)
#   Tourinnes-la-Grosse  (1863) (14500)
#   Trenzano  (1856) (11800)
#   Treysa  (1916) (63000)
#   Tuan Tuc  (1921) (13100)
#   Tuxtuac  (1975) (30000)
#   Tysnes Island  (1884) (19860)
#   Uberaba  (1903) (40000)
#   Udei Station  (1927) (103000)
#   Uzcudun  (1948) (20000)
#   Valera  (1972) (50000)
#   Vengerovo  (1950) (10800)
#   Veramin  (1880) (54000)
#   Vigarano  (1910) (15000)
#   Vouillé  (1831) (20000)
#   Walters  (1946) (28100)
#   Weston  (1807) (150000)
#   Wiluna  (1967) (150000)
#   Wold Cottage  (1795) (25000)
#   Woolgorong  (1960) (36000)
#   Wuan  (1986) (50000)
#   Xingyang  (1977) (75500)
#   Yangchiang  (1954) (20000)
#   Yatoor  (1852) (13600)
#   Yardymly  (1959) (150200)
#   Yonozu  (1837) (31650)
#   Zagami  (1962) (18000)
#   Zag  (1998) (175000)
#   Zavid  (1897) (95000)
#   Zaoyang  (1984) (14250)
#   Zemaitkiemis  (1933) (44100)
#   Zhaodong  (1984) (42000)
#   Zhovtnevyi  (1938) (107000)
#   Abbott  (1951) (21100)
#   Acfer 329  (2001) (30000)
#   Acfer 336  (2002) (19400)
#   Acfer 353  (2001) (11935)
#   Acfer 379  (2004) (14764)
#   Achilles  (1924) (16000)
#   Acme  (1947) (75000)
#   Acuña  (1981) (217700)
#   ad-Dahbubah  (1961) (90000)
#   Admire  (1881) (180000)
#   Adrian  (1936) (22600)
#   Adzhi-Bogdo (iron)  (1952) (582000)
#   Aggie Creek  (1942) (43000)
#   Agoudal  (2000) (100000)
#   Agua Blanca  (1938) (49000)
#   Al Haggounia 001  (2006) (3000000)
#   Ahumada  (1909) (52600)
#   Ainsworth  (1907) (80650)
#   Al Huqf 064  (2002) (12834)
#   Alamogordo  (1938) (13600)
#   Alatage  (1959) (37500)
#   Albin (pallasite)  (1915) (37600)
#   Albin (stone)  (1949) (15400)
#   Albion  (1966) (12280)
#   Aldama (a)  (1985) (11000)
#   Alikatnima  (1931) (20000)
#   Aliskerovo  (1977) (58400)
#   al-Jimshan  (1955) (11450)
#   Alkhamasin  (1973) (1200000)
#   Allan Hills 84005  (1984) (12000)
#   Allan Hills 84006  (1984) (16000)
#   Allan Hills A76001  (1976) (20151)
#   Allan Hills A76003  (1976) (10495)
#   Allan Hills A76009  (1976) (407000)
#   Allan Hills A77226  (1977) (15323)
#   Allan Hills A77250  (1977) (10555)
#   Allan Hills A77283  (1977) (10510)
#   Jiddat al Harasis 574  (2009) (13000)
#   Jiddat al Harasis 628  (2009) (16000)
#   Jiddat al Harasis 664  (2011) (12175)
#   Joe Wright Mountain  (1884) (42600)
#   Johnson City  (1937) (10400)
#   Juanita de Angeles  (1992) (85000)
#   Julesburg  (1983) (57900)
#   Juncal  (1866) (104000)
#   Kaffir (d)  (1981) (26760)
#   Kalahari 009  (1999) (13500)
#   Kaldoonera Hill  (1956) (12000)
#   Kansas City (1903)  (1903) (36000)
#   Karasburg  (1964) (12000)
#   Kargapole  (1961) (21800)
#   Karee Kloof  (1914) (92100)
#   Kaufman  (1893) (23000)
#   Kelly  (1937) (44300)
#   Kendall County  (1887) (21000)
#   Kenna  (1972) (10900)
#   Kenton County  (1889) (194000)
#   Keyes  (1939) (142000)
#   Kielpa  (1948) (13600)
#   Kifkakhsyagan  (1972) (18800)
#   Kimble County  (1918) (153800)
#   Kingston  (1891) (12900)
#   Klamath Falls  (1952) (17000)
#   Knowles  (1903) (161000)
#   Kodaikanal  (1898) (15900)
#   Kokstad  (1884) (341000)
#   Koltsovo  (2004) (20020)
#   Kopjes Vlei  (1914) (13600)
#   Korra Korrabes  (1996) (140000)
#   Kouga Mountains  (1903) (1173000)
#   Krasnojarsk  (1749) (700000)
#   Kress (a)  (1951) (12500)
#   Kulnine  (1886) (55300)
#   Kumerina  (1937) (53500)
#   Kumtag  (2008) (26000)
#   Kyancutta  (1932) (32700)
#   La Caille  (1828) (626000)
#   La Lande  (1933) (30000)
#   La Grange  (1860) (50800)
#   La Porte  (1900) (14540)
#   La Primitiva  (1888) (27400)
#   La Villa  (1956) (19800)
#   Ladder Creek  (1937) (35100)
#   Laguna Manantiales  (1945) (92000)
#   Lahmada 009  (1999) (70000)
#   Lahoma  (1963) (21800)
#   Lake Brown  (1919) (23400)
#   Lake Grace  (1956) (10500)
#   Lake Labyrinth  (1924) (25850)
#   Lake Murray  (1933) (270000)
#   Lakewood  (1955) (46500)
#   Lamesa  (1981) (16900)
#   Lamont  (1940) (38690)
#   Landes  (1930) (69800)
#   Lancaster County  (1903) (13000)
#   Lanton  (1932) (13780)
#   Larned  (1977) (28100)
#   Lenarto  (1814) (108500)
#   Leon  (1943) (30000)
#   Lewis Cliff 85319  (1985) (11491)
#   Lewis Cliff 85320  (1985) (110224)
#   Liangcheng  (1959) (200000)
#   Lime Creek  (1834) (20000)
#   Linwood  (1940) (46000)
#   Little River (b)  (1965) (11700)
#   Littlerock  (1979) (19050)
#   Lixian  (2005) (43000)
#   Lone Tree  (1971) (20676)
#   Lonewolf Nunataks 94104  (1994) (10172)
#   Long Island  (1891) (564000)
#   Longchang  (1781) (158500)
#   Longtian  (1991) (350000)
#   Loreto  (1896) (94800)
#   Los Reyes  (1897) (19500)
#   Los Sauces  (1937) (997000)
#   Los Vientos 002  (2010) (30750)
#   Los Vientos 003  (2011) (25450)
#   Los Vientos 004  (2011) (29300)
#   Los Vientos 028  (2012) (12110)
#   Sinawan 001  (1991) (28600)
#   Singhur  (1847) (14180)
#   Skookum  (1905) (16000)
#   Smara  (2000) (12870)
#   Smithonia  (1940) (69900)
#   Smithville  (1840) (70500)
#   Snyder  (1983) (16900)
#   Social Circle  (1927) (99300)
#   Soledade  (1986) (68000)
#   Somervell County  (1919) (11800)
#   Souslovo  (1997) (19300)
#   South Dahna  (1957) (275000)
#   Spearman  (1934) (10400)
#   Springlake  (1980) (17300)
#   Springwater  (1931) (67600)
#   Ssyromolotovo  (1873) (217000)
#   St. Genevieve County  (1888) (244500)
#   Starvation Lake  (1975) (12000)
#   Staunton  (1869) (43500)
#   Steinbach  (1724) (98000)
#   Stump Spring 083  (2010) (13700)
#   Sueilila  (2005) (13266)
#   Sukhoj Liman  (1987) (48000)
#   Susuman  (1957) (18900)
#   Sychevka  (1988) (65000)
#   Tafassasset  (2000) (114000)
#   Taicang  (1928) (20000)
#   Taiban  (1934) (25000)
#   Talpa  (1963) (13000)
#   Tamarugal  (1903) (320000)
#   Tambo Quemado  (1950) (141000)
#   Tamentit  (1864) (510000)
#   Tamir-Tsetserleg  (1956) (173000)
#   Tanezrouft 028  (1991) (15000)
#   Tanezrouft 065  (2002) (30000)
#   Tanezrouft 072  (2002) (62285)
#   Taoudenni  (2007) (24370)
#   Tanokami Mountain  (1885) (174000)
#   Tawallah Valley  (1939) (75750)
#   Tazewell  (1853) (27000)
#   Tell  (1930) (16600)
#   Tendo  (1910) (10100)
#   Teplá  (1909) (17000)
#   Texline  (1937) (26200)
#   Thiel Mountains  (1962) (31700)
#   Thule  (1955) (48600)
#   Thunda  (1881) (62100)
#   Tianlin  (1956) (300000)
#   Tiberrhamine  (1967) (107000)
#   Tieraco Creek  (1922) (41700)
#   Tiffa 001  (1997) (26900)
#   Tinnie  (1978) (15300)
#   Tlacotepec  (1903) (71000)
#   Tishomingo  (1965) (260000)
#   Toluca  (1776) (3000000)
#   Tombigbee River  (1859) (43000)
#   Tonganoxie  (1886) (11800)
#   Tostado  (1945) (22000)
#   Toubil River  (1891) (22000)
#   Trenton  (1858) (505000)
#   Travis County (a)  (1889) (175400)
#   Toufassour  (2007) (73300)
#   Tres Castillos  (1992) (150000)
#   Tsarev  (1968) (1225300)
#   Tryon  (1934) (15900)
#   Tucson  (1850) (975000)
#   Tulia (a)  (1917) (86000)
#   Tulia (d)  (1981) (17700)
#   Turtle River  (1953) (22390)
#   Twentynine Palms  (1944) (19700)
#   Twannberg  (1984) (20689)
#   Two Buttes (a)  (1962) (19700)
#   Twodot  (1999) (21400)
#   Uegit  (1921) (252000)
#   Umbarger  (1954) (13000)
#   Unter-Mässing  (1920) (80000)
#   Uruachic  (1989) (13000)
#   Uruaçu  (1992) (72500)
#   Ust-Nyukzha  (1992) (44000)
#   Uwet  (1903) (54000)
#   Uwharrie  (1930) (72700)
#   Vaalbult  (1921) (11800)
#   Vaca Muerta  (1861) (3828000)
#   Veliko-Nikolaevsky Priisk  (1902) (24267)
#   Verissimo  (1965) (14000)
#   Verkhne Udinsk  (1854) (18000)
#   Vera  (1941) (80000)
#   Vermillion  (1991) (34360)
#   Villedieu  (1890) (14000)
#   Vitoria da Conquista  (2007) (10500)
#   Vulcan  (1962) (19000)
#   Vyatka  (1991) (45000)
#   Wabar  (1863) (2550000)
#   Waconda  (1873) (50000)
#   View Hill  (1952) (33600)
#   Wagon Mound  (1932) (87500)
#   Waka  (1963) (11875)
#   Waldron Ridge  (1887) (13600)
#   Wallapai  (1927) (430000)
#   Walker County  (1832) (74800)
#   Waltman  (1948) (23410)
#   Warburton Range  (1963) (56930)
#   Waterville  (1917) (37125)
#   Watson 001  (1972) (93000)
#   Wayside  (1973) (23600)
#   Weaver Mountains  (1898) (38800)
#   Weekeroo Station  (1924) (94200)
#   Weldona  (1934) (27700)
#   Wellington  (1955) (13400)
#   Wellman (a)  (1940) (55000)
#   Wellman (c)  (1964) (45000)
#   Wichita County  (1836) (145000)
#   Wildara  (1968) (500000)
#   Wilder  (1982) (26600)
#   Willamette  (1902) (15500000)
#   Willard (b)  (1934) (12700)
#   Willow Grove  (1995) (11700)
#   Willow Creek  (1914) (51000)
#   Winburg  (1881) (50000)
#   Windimurra  (2004) (30000)
#   Winona  (1928) (24000)
#   Wolf Creek  (1947) (760000)
#   Wolsey  (1981) (74830)
#   Wonyulgunna  (1937) (37800)
#   Woodbine  (1953) (48200)
#   Woodward County  (1923) (45500)
#   Wooramel  (1969) (71000)
#   Wooster  (1858) (22700)
#   Wu-chu-mu-ch'in  (1920) (68860)
#   Wynella  (1945) (40000)
#   Xifu  (2004) (3000000)
#   Xinyi  (1975) (69000)
#   Yamato 000593  (2000) (13713)
#   Yamato 75102  (1975) (11000)
#   Yamato 791717  (1979) (25322)
#   Yamato 793235  (1979) (18126)
#   Yamato 81124  (1981) (10790)
#   Yanhuitlan  (1825) (421000)
#   Ybbsitz  (1977) (15000)
#   Yelland Dry Lake  (2007) (76000)
#   Yenberrie  (1918) (132000)
#   Yingde  (1964) (3000000)
#   Yilmia  (1969) (40000)
#   Yongning  (1971) (60000)
#   Youanmi  (1917) (118400)
#   Youndegin  (1884) (3800000)
#   Youxi  (2006) (218000)
#   Ysleta  (1914) (140700)
#   Zacatecas (1792)  (1792) (1000000)
#   Zagora  (1987) (50000)
#   Zapaliname  (1998) (85000)
#   Zerhamra  (1967) (630000)
#   Zerkaly  (1956) (16000)
#   Zhigansk  (1966) (900000)
#   Zhongxiang  (1981) (100000)
#   Zhaoping  (1983) (2000000)
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# ---
#
# ## Check Your Understanding
#
# Using `geojson["features"]`, build a map with **two named layers**:
#
# - `"Points"` — all Point features, styled blue (`#2980b9`)
# - `"Areas"` — all Polygon features, styled green (`#27ae60`), `fillOpacity` 0.4
#
# Add a `LayersControl` so both can be toggled.
#
# ```python
# # your answer here
# ```

# %% [markdown]
# ## Next
#
# In [04 — Interactive Maps](../04-Interactive_Maps/00-Map_Events.ipynb), we add event handling — letting users click the map and drive what the map shows.
